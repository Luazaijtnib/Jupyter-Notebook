# %%
#name: Aijaz Hussain , Roll no. : 211103058, Branch: Computer Science
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from 'student_data.csv'
data = pd.read_csv('student_data.csv')
# Check for missing values
missing_values = data.isnull().sum()

# Summary statistics
summary_stats = data.describe()

# Explore data
sns.pairplot(data[['math_score', 'english_score', 'history_score', 'attendance_rate']])
plt.show()

# Calculate correlations
correlation_matrix = data[['math_score', 'english_score', 'history_score', 'attendance_rate']].corr()

# Display correlation matrix
print(correlation_matrix)
# Out:
#                  math_score  english_score  history_score  attendance_rate
# math_score         1.000000       0.103343      -0.034572        -0.003638
# english_score      0.103343       1.000000      -0.101649         0.067966
# history_score     -0.034572      -0.101649       1.000000        -0.076665
# attendance_rate   -0.003638       0.067966      -0.076665         1.000000

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from CSV file
file_path = 'student_data.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
data.head()

# Compute correlations between attendance rate and subject scores
correlation_data = data[['attendance_rate', 'math_score', 'english_score', 'history_score']].corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_data)

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_data, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# Display the correlation values for attendance rate
attendance_correlation = correlation_data['attendance_rate']
print("\nCorrelation of attendance rate with other variables:")
print(attendance_correlation)
# Out:
# Correlation Matrix:
#                  attendance_rate  math_score  english_score  history_score
# attendance_rate         1.000000   -0.003638       0.067966      -0.076665
# math_score             -0.003638    1.000000       0.103343      -0.034572
# english_score           0.067966    0.103343       1.000000      -0.101649
# history_score          -0.076665   -0.034572      -0.101649       1.000000
# Correlation of attendance rate with other variables:
# attendance_rate    1.000000
# math_score        -0.003638
# english_score      0.067966
# history_score     -0.076665
# Name: attendance_rate, dtype: float64
